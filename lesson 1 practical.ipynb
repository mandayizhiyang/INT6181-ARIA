# %%
def print_receipt(item_name, price):
    # FAULT: Attempting to concatenate a String and a Float
    message = "You purchased " + item_name + " for $" + str(price)
    print (message)
 
print_receipt("Coffee", 3.50)
# Out:
# You purchased Coffee for $3.5

# %%
'{:-^20}'.format('Python')
# Out:
# '-------Python-------'

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
items = ['apple', 'banana', 'cherry']
for i in range(len(items)):
    print(f"{i}: {items[i]}")
# Out:
# 0: apple
# 1: banana
# 2: cherry

# %%
items = ['apple', 'banana', 'cherry']
for i, item in enumerate(items):
    print(f"{i}: {item}")
# Out:
# 0: apple
# 1: banana
# 2: cherry

# %%
active_users = ["Alice", "Bob", "Charlie", "Dave"]
for user in active_users:
    if user.startswith("B") or user.startswith("C"):
        active_users.remove(user)
 
print(active_users)
# Out:
# ['Alice', 'Charlie', 'Dave']

# %%
def add_to_cart(item, cart=[]):
    cart.append(item)
    return cart
 
user1_cart = add_to_cart("Shoes")
user2_cart = add_to_cart("Hat")
 
print (user1_cart,user2_cart)
# Out:
# ['Shoes', 'Hat'] ['Shoes', 'Hat']
